# %% [markdown]
# ## **Importing Dependencies**

# %%
import os
import SimpleITK as sitk
import numpy as np

# %% [markdown]
# ## **Data Directories**

# %%
train_adc_dir = r"E:\University\Masters\Semester 2\DL\Term Project\Data\BONBID2023_Train\1ADC_ss"
train_z_adc_dir = r"E:\University\Masters\Semester 2\DL\Term Project\Data\BONBID2023_Train\2Z_ADC"
train_label_dir = r"E:\University\Masters\Semester 2\DL\Term Project\Data\BONBID2023_Train\3LABEL"
val_adc_dir = r"E:\University\Masters\Semester 2\DL\Term Project\Data\BONBID2023_Val\1ADC_ss"
val_z_adc_dir = r"E:\University\Masters\Semester 2\DL\Term Project\Data\BONBID2023_Val\2Z_ADC"
val_label_dir = r"E:\University\Masters\Semester 2\DL\Term Project\Data\BONBID2023_Val\3LABEL"
preprocessed_dir = r"E:\University\Masters\Semester 2\DL\Term Project\Data\Preprocessed"
train_output_dir = os.path.join(preprocessed_dir, "Train")
val_output_dir = os.path.join(preprocessed_dir, "Val")

# %% [markdown]
# ## **Exploring Map and Mask Sizes**

# %%
# List of directories to scan
directories = [
    train_adc_dir,
    train_z_adc_dir,
    train_label_dir,
    val_adc_dir,
    val_z_adc_dir,
    val_label_dir,
]

# %%
# Function to calculate the average, maximum, and minimum size from a directory
def calculate_sizes(directory):
    total_size = [0, 0, 0] 
    max_size = [0, 0, 0]  
    min_size = [float("inf"), float("inf"), float("inf")]  
    file_count = 0 

    for file_name in os.listdir(directory):
        if file_name.endswith(".mha"):
            file_path = os.path.join(directory, file_name)
            try:
                image = sitk.ReadImage(file_path)
                size = image.GetSize() 
                total_size = [t + s for t, s in zip(total_size, size)]
                max_size = [max(m, s) for m, s in zip(max_size, size)]
                min_size = [min(m, s) for m, s in zip(min_size, size)]
                file_count += 1
            except Exception as e:
                print(f"Error reading file {file_path}: {e}")

    if file_count > 0:
        average_size = tuple(t // file_count for t in total_size)
        return average_size, tuple(max_size), tuple(min_size)
    else:
        return (0, 0, 0), (0, 0, 0), (0, 0, 0)

# %%
# Iterate over all directories and find sizes
overall_max_average_size = (0, 0, 0)
overall_max_size = (0, 0, 0)
overall_min_size = (float("inf"), float("inf"), float("inf"))

for dir_path in directories:
    dir_average_size, dir_max_size, dir_min_size = calculate_sizes(dir_path)
    overall_max_average_size = tuple(max(o, a) for o, a in zip(overall_max_average_size, dir_average_size))
    overall_max_size = tuple(max(o, m) for o, m in zip(overall_max_size, dir_max_size))
    overall_min_size = tuple(min(o, m) for o, m in zip(overall_min_size, dir_min_size))
    
    print(f"Directory: {dir_path}")
    print(f"  Average size: {dir_average_size}")
    print(f"  Maximum size: {dir_max_size}")
    print(f"  Minimum size: {dir_min_size}")
# Out:
# Directory: E:\University\Masters\Semester 2\DL\Term Project\Data\BONBID2023_Train\1ADC_ss
#   Average size: (176, 176, 37)
#   Maximum size: (256, 256, 64)
#   Minimum size: (128, 128, 16)
# Directory: E:\University\Masters\Semester 2\DL\Term Project\Data\BONBID2023_Train\2Z_ADC
#   Average size: (176, 176, 37)
#   Maximum size: (256, 256, 64)
#   Minimum size: (128, 128, 16)
# Directory: E:\University\Masters\Semester 2\DL\Term Project\Data\BONBID2023_Train\3LABEL
#   Average size: (176, 176, 37)
#   Maximum size: (256, 256, 64)
#   Minimum size: (128, 128, 16)
# Directory: E:\University\Masters\Semester 2\DL\Term Project\Data\BONBID2023_Val\1ADC_ss
#   Average size: (136, 132, 27)
#   Maximum size: (160, 144, 51)
#   Minimum size: (128, 128, 16)
# Directory: E:\University\Masters\Semester 2\DL\Term Project\Data\BONBID2023_Val\2Z_ADC
#   Average size: (136, 132, 27)
#   Maximum size: (160, 144, 51)
#   Minimum size: (128, 128, 16)
# Directory: E:\University\Masters\Semester 2\DL\Term Project\Data\BONBID2023_Val\3LABEL
#   Average size: (136, 132, 27)
#   Maximum size: (160, 144, 51)
#   Minimum size: (128, 128, 16)

# %%
print(f"\nOverall maximum average size across all directories: {overall_max_average_size}")
print(f"Overall maximum size across all directories: {overall_max_size}")
print(f"Overall minimum size across all directories: {overall_min_size}")
# Out:
# Overall maximum average size across all directories: (176, 176, 37)
# Overall maximum size across all directories: (256, 256, 64)
# Overall minimum size across all directories: (128, 128, 16)

# %% [markdown]
# ## **Resampling Maps and Masks**
# * 3D medical images are memory intensive and so to reduce computational overhead during training, the data is preprocessed offline as doing it on-the-fly can lead to duplicate memory allocation.
# * First preprocessing step is to resample maps and masks to a fixed size to make Pytorch batching possible and help model learn efficiently without being biased by size variations. Maps and labels are resampled to (H,W,D) -> (192,192,32) which is maximum of average dimension across all directories, rounded to a multiple of 2^4=16 (total downsampling factor of traditional UNet) to ensure clean downsampling and upsampling (without fractional sizes that require inconsistent padding). For maps resizing is done using Trilinear interpolation because it provides smooth transitions in intensity values preserving the overall structure without introducing artifacts and for mask Nearest Neighbor interpolation is used because it preserves discrete class boundaries, preventing the creation of intermediate invalid label values. For example, 0.5 for a binary mask.
# We didn't resample to maximum dimension across all directories purely due to memory constraints as otherwise we believe it to be the superior choice and we didn't resample to minimum dimension across all directories as it would lead to too much data loss. Current choice strikes a balance between preserving structural detail and memory efficiency.
# * In the second step, the resampled (resized) maps' intensities are normalized individually using mean and standard deviation to make the model more robust by mitigating differences in scanners and patient anatomy (along with the first step above).
# * Lastly, both adc and z_adc maps are concatenated (stacked on top of each other) to make a 2-channel input (C,H,W,D) -> (2,192,192,32) for UNet to allow the model to leverage information from both modalities.

# %%
# Create the output directories
os.makedirs(train_output_dir, exist_ok=True)
os.makedirs(val_output_dir, exist_ok=True)
os.makedirs(os.path.join(train_output_dir, "MAP"), exist_ok=True)
os.makedirs(os.path.join(train_output_dir, "LABEL"), exist_ok=True)
os.makedirs(os.path.join(val_output_dir, "MAP"), exist_ok=True)
os.makedirs(os.path.join(val_output_dir, "LABEL"), exist_ok=True)

# Metadata dictionary
metadata = {}

# Helper function to load .mha files
def load_mha_file(file_path):
    img = sitk.ReadImage(file_path)
    img_array = sitk.GetArrayFromImage(img)
    return img_array, img

# Helper Function to normalize image intensity using mean and standard deviation
def normalize_intensity(img_array):
    mean = np.mean(img_array)
    std = np.std(img_array)
    return (img_array - mean) / std

# Helper Function to save processed .mha images
def save_mha_image(img, output_path):
    sitk.WriteImage(img, output_path)

# Helper function to resample images to a fixed size
def resample_image(image, target_size=(192, 192, 32), is_mask=False): # SimpleITK convention (x,y,z) -> (W,H,D)
    original_size = image.GetSize() 
    original_spacing = image.GetSpacing()  
    
    # Compute new spacing based on target size
    new_spacing = [
        original_spacing[i] * (original_size[i] / target_size[i])
        for i in range(3)
    ]
    
    # Set up resampler
    resampler = sitk.ResampleImageFilter()
    resampler.SetSize(target_size)
    resampler.SetOutputSpacing(new_spacing)
    resampler.SetOutputOrigin(image.GetOrigin())
    resampler.SetOutputDirection(image.GetDirection())
    
    # Use nearest neighbor for binary masks, linear interpolation otherwise
    if is_mask:
        resampler.SetInterpolator(sitk.sitkNearestNeighbor)
    else:
        resampler.SetInterpolator(sitk.sitkLinear)

    # Apply resizing
    resized_image = resampler.Execute(image)
    return resized_image

# Function to process the dataset
def process_dataset(adc_dir, z_adc_dir, label_dir, output_dir, dataset_name):
    adc_files = {file_name.replace("-ADC_ss.mha", "") for file_name in os.listdir(adc_dir)}
    z_adc_files = {file_name.replace("Zmap_", "").replace("-ADC_smooth2mm_clipped10.mha", "") for file_name in os.listdir(z_adc_dir)}
    label_files = {file_name.replace("_lesion.mha", "") for file_name in os.listdir(label_dir)}

    common_files = adc_files.intersection(z_adc_files).intersection(label_files)
    print(f"Common files for {dataset_name}: {len(common_files)}")

    for base_name in common_files:
        adc_path = os.path.join(adc_dir, f"{base_name}-ADC_ss.mha")
        z_adc_path = os.path.join(z_adc_dir, f"Zmap_{base_name}-ADC_smooth2mm_clipped10.mha")
        label_path = os.path.join(label_dir, f"{base_name}_lesion.mha")

        # Load images
        _, adc_sitk = load_mha_file(adc_path)
        _, z_adc_sitk = load_mha_file(z_adc_path)
        _, label_sitk = load_mha_file(label_path)
        print('Original ADC Shape', sitk.GetArrayFromImage(adc_sitk).shape)
        print('Original Z_ADC Shape', sitk.GetArrayFromImage(z_adc_sitk).shape)
        print('Original Label Shape', sitk.GetArrayFromImage(label_sitk).shape)

        # Resample images
        adc_resampled = resample_image(adc_sitk, is_mask=False)
        z_adc_resampled = resample_image(z_adc_sitk, is_mask=False)

        # Normalize intensity for ADC and Z-ADC
        adc_resampled_array = normalize_intensity(sitk.GetArrayFromImage(adc_resampled))
        z_adc_resampled_array = normalize_intensity(sitk.GetArrayFromImage(z_adc_resampled))

        # Resample binary mask (label)
        label_resampled = resample_image(label_sitk, is_mask=True)

        # Concatenate along channel axis (C, D, H, W)
        concatenated_map = np.stack((adc_resampled_array, z_adc_resampled_array), axis=0)
        print('Concatenated Map Shape', concatenated_map.shape)
        print('Resampled Label Shape', sitk.GetArrayFromImage(label_resampled).shape)
        concatenated_map_sitk = sitk.GetImageFromArray(concatenated_map)

        # Save MAP and label
        save_mha_image(concatenated_map_sitk, os.path.join(output_dir, "MAP", f"{base_name}_concatenated.mha"))
        save_mha_image(label_resampled, os.path.join(output_dir, "LABEL", f"{base_name}_lesion.mha"))
        print(f"Processed and saved for {base_name} in {dataset_name}")

# Process datasets
process_dataset(train_adc_dir, train_z_adc_dir, train_label_dir, train_output_dir, "Train")
process_dataset(val_adc_dir, val_z_adc_dir, val_label_dir, val_output_dir, "Val")
# Out:
# Common files for Train: 85
# Original ADC Shape (57, 128, 128)
# Original Z_ADC Shape (57, 128, 128)
# Original Label Shape (57, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_306-VISIT_01 in Train
# Original ADC Shape (23, 128, 128)
# Original Z_ADC Shape (23, 128, 128)
# Original Label Shape (23, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_010-VISIT_01 in Train
# Original ADC Shape (48, 256, 256)
# Original Z_ADC Shape (48, 256, 256)
# Original Label Shape (48, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_105-VISIT_01 in Train
# Original ADC Shape (46, 256, 256)
# Original Z_ADC Shape (46, 256, 256)
# Original Label Shape (46, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_153-VISIT_01 in Train
# Original ADC Shape (20, 160, 160)
# Original Z_ADC Shape (20, 160, 160)
# Original Label Shape (20, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_445-VISIT_01 in Train
# Original ADC Shape (64, 128, 128)
# Original Z_ADC Shape (64, 128, 128)
# Original Label Shape (64, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_174-VISIT_01 in Train
# Original ADC Shape (28, 256, 256)
# Original Z_ADC Shape (28, 256, 256)
# Original Label Shape (28, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_209-VISIT_01 in Train
# Original ADC Shape (54, 128, 128)
# Original Z_ADC Shape (54, 128, 128)
# Original Label Shape (54, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_275-VISIT_01 in Train
# Original ADC Shape (18, 160, 160)
# Original Z_ADC Shape (18, 160, 160)
# Original Label Shape (18, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_448-VISIT_01 in Train
# Original ADC Shape (23, 128, 128)
# Original Z_ADC Shape (23, 128, 128)
# Original Label Shape (23, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_405-VISIT_01 in Train
# Original ADC Shape (20, 160, 160)
# Original Z_ADC Shape (20, 160, 160)
# Original Label Shape (20, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_453-VISIT_01 in Train
# Original ADC Shape (21, 160, 160)
# Original Z_ADC Shape (21, 160, 160)
# Original Label Shape (21, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_379-VISIT_01 in Train
# Original ADC Shape (25, 256, 256)
# Original Z_ADC Shape (25, 256, 256)
# Original Label Shape (25, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_214-VISIT_01 in Train
# Original ADC Shape (52, 128, 128)
# Original Z_ADC Shape (52, 128, 128)
# Original Label Shape (52, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_393-VISIT_01 in Train
# Original ADC Shape (20, 160, 160)
# Original Z_ADC Shape (20, 160, 160)
# Original Label Shape (20, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_457-VISIT_01 in Train
# Original ADC Shape (50, 128, 128)
# Original Z_ADC Shape (50, 128, 128)
# Original Label Shape (50, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_362-VISIT_01 in Train
# Original ADC Shape (25, 160, 160)
# Original Z_ADC Shape (25, 160, 160)
# Original Label Shape (25, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_444-VISIT_01 in Train
# Original ADC Shape (23, 256, 256)
# Original Z_ADC Shape (23, 256, 256)
# Original Label Shape (23, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_433-VISIT_01 in Train
# Original ADC Shape (52, 128, 128)
# Original Z_ADC Shape (52, 128, 128)
# Original Label Shape (52, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_234-VISIT_01 in Train
# Original ADC Shape (24, 160, 160)
# Original Z_ADC Shape (24, 160, 160)
# Original Label Shape (24, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_378-VISIT_01 in Train
# Original ADC Shape (19, 160, 160)
# Original Z_ADC Shape (19, 160, 160)
# Original Label Shape (19, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_447-VISIT_01 in Train
# Original ADC Shape (45, 256, 256)
# Original Z_ADC Shape (45, 256, 256)
# Original Label Shape (45, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_197-VISIT_01 in Train
# Original ADC Shape (52, 128, 128)
# Original Z_ADC Shape (52, 128, 128)
# Original Label Shape (52, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_359-VISIT_01 in Train
# Original ADC Shape (45, 256, 256)
# Original Z_ADC Shape (45, 256, 256)
# Original Label Shape (45, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_069-VISIT_01 in Train
# Original ADC Shape (40, 256, 256)
# Original Z_ADC Shape (40, 256, 256)
# Original Label Shape (40, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_109-VISIT_01 in Train
# Original ADC Shape (27, 256, 256)
# Original Z_ADC Shape (27, 256, 256)
# Original Label Shape (27, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_215-VISIT_01 in Train
# Original ADC Shape (24, 256, 256)
# Original Z_ADC Shape (24, 256, 256)
# Original Label Shape (24, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_376-VISIT_01 in Train
# Original ADC Shape (23, 128, 128)
# Original Z_ADC Shape (23, 128, 128)
# Original Label Shape (23, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_014-VISIT_01 in Train
# Original ADC Shape (56, 128, 128)
# Original Z_ADC Shape (56, 128, 128)
# Original Label Shape (56, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_346-VISIT_01 in Train
# Original ADC Shape (28, 160, 160)
# Original Z_ADC Shape (28, 160, 160)
# Original Label Shape (28, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_439-VISIT_01 in Train
# Original ADC Shape (50, 128, 128)
# Original Z_ADC Shape (50, 128, 128)
# Original Label Shape (50, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_263-VISIT_01 in Train
# Original ADC Shape (52, 128, 128)
# Original Z_ADC Shape (52, 128, 128)
# Original Label Shape (52, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_403-VISIT_01 in Train
# Original ADC Shape (16, 160, 160)
# Original Z_ADC Shape (16, 160, 160)
# Original Label Shape (16, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_446-VISIT_01 in Train
# Original ADC Shape (64, 128, 128)
# Original Z_ADC Shape (64, 128, 128)
# Original Label Shape (64, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_286-VISIT_01 in Train
# Original ADC Shape (54, 128, 128)
# Original Z_ADC Shape (54, 128, 128)
# Original Label Shape (54, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_290-VISIT_01 in Train
# Original ADC Shape (49, 256, 256)
# Original Z_ADC Shape (49, 256, 256)
# Original Label Shape (49, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_144-VISIT_01 in Train
# Original ADC Shape (18, 160, 160)
# Original Z_ADC Shape (18, 160, 160)
# Original Label Shape (18, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_441-VISIT_01 in Train
# Original ADC Shape (16, 160, 160)
# Original Z_ADC Shape (16, 160, 160)
# Original Label Shape (16, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_377-VISIT_01 in Train
# Original ADC Shape (46, 256, 256)
# Original Z_ADC Shape (46, 256, 256)
# Original Label Shape (46, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_064-VISIT_01 in Train
# Original ADC Shape (55, 128, 128)
# Original Z_ADC Shape (55, 128, 128)
# Original Label Shape (55, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_323-VISIT_01 in Train
# Original ADC Shape (60, 256, 256)
# Original Z_ADC Shape (60, 256, 256)
# Original Label Shape (60, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_262-VISIT_01 in Train
# Original ADC Shape (49, 256, 256)
# Original Z_ADC Shape (49, 256, 256)
# Original Label Shape (49, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_415-VISIT_01 in Train
# Original ADC Shape (42, 256, 256)
# Original Z_ADC Shape (42, 256, 256)
# Original Label Shape (42, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_074-VISIT_01 in Train
# Original ADC Shape (50, 128, 128)
# Original Z_ADC Shape (50, 128, 128)
# Original Label Shape (50, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_309-VISIT_01 in Train
# Original ADC Shape (59, 128, 128)
# Original Z_ADC Shape (59, 128, 128)
# Original Label Shape (59, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_310-VISIT_01 in Train
# Original ADC Shape (23, 128, 128)
# Original Z_ADC Shape (23, 128, 128)
# Original Label Shape (23, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_015-VISIT_01 in Train
# Original ADC Shape (52, 128, 128)
# Original Z_ADC Shape (52, 128, 128)
# Original Label Shape (52, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_348-VISIT_01 in Train
# Original ADC Shape (64, 128, 128)
# Original Z_ADC Shape (64, 128, 128)
# Original Label Shape (64, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_173-VISIT_01 in Train
# Original ADC Shape (20, 160, 160)
# Original Z_ADC Shape (20, 160, 160)
# Original Label Shape (20, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_440-VISIT_01 in Train
# Original ADC Shape (60, 128, 128)
# Original Z_ADC Shape (60, 128, 128)
# Original Label Shape (60, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_305-VISIT_01 in Train
# Original ADC Shape (18, 160, 160)
# Original Z_ADC Shape (18, 160, 160)
# Original Label Shape (18, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_303-VISIT_01 in Train
# Original ADC Shape (20, 160, 160)
# Original Z_ADC Shape (20, 160, 160)
# Original Label Shape (20, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_452-VISIT_01 in Train
# Original ADC Shape (48, 256, 256)
# Original Z_ADC Shape (48, 256, 256)
# Original Label Shape (48, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_071-VISIT_01 in Train
# Original ADC Shape (43, 256, 256)
# Original Z_ADC Shape (43, 256, 256)
# Original Label Shape (43, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_101-VISIT_01 in Train
# Original ADC Shape (25, 256, 256)
# Original Z_ADC Shape (25, 256, 256)
# Original Label Shape (25, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_442-VISIT_01 in Train
# Original ADC Shape (23, 128, 128)
# Original Z_ADC Shape (23, 128, 128)
# Original Label Shape (23, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_028-VISIT_01 in Train
# Original ADC Shape (45, 256, 256)
# Original Z_ADC Shape (45, 256, 256)
# Original Label Shape (45, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_338-VISIT_01 in Train
# Original ADC Shape (17, 160, 160)
# Original Z_ADC Shape (17, 160, 160)
# Original Label Shape (17, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_373-VISIT_01 in Train
# Original ADC Shape (19, 160, 160)
# Original Z_ADC Shape (19, 160, 160)
# Original Label Shape (19, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_437-VISIT_01 in Train
# Original ADC Shape (17, 160, 160)
# Original Z_ADC Shape (17, 160, 160)
# Original Label Shape (17, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_432-VISIT_01 in Train
# Original ADC Shape (25, 256, 256)
# Original Z_ADC Shape (25, 256, 256)
# Original Label Shape (25, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_272-VISIT_01 in Train
# Original ADC Shape (54, 128, 128)
# Original Z_ADC Shape (54, 128, 128)
# Original Label Shape (54, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_231-VISIT_01 in Train
# Original ADC Shape (16, 160, 160)
# Original Z_ADC Shape (16, 160, 160)
# Original Label Shape (16, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_438-VISIT_01 in Train
# Original ADC Shape (28, 160, 160)
# Original Z_ADC Shape (28, 160, 160)
# Original Label Shape (28, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_435-VISIT_01 in Train
# Original ADC Shape (56, 256, 256)
# Original Z_ADC Shape (56, 256, 256)
# Original Label Shape (56, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_178-VISIT_01 in Train
# Original ADC Shape (20, 160, 160)
# Original Z_ADC Shape (20, 160, 160)
# Original Label Shape (20, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_449-VISIT_01 in Train
# Original ADC Shape (28, 160, 160)
# Original Z_ADC Shape (28, 160, 160)
# Original Label Shape (28, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_458-VISIT_01 in Train
# Original ADC Shape (50, 128, 128)
# Original Z_ADC Shape (50, 128, 128)
# Original Label Shape (50, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_331-VISIT_01 in Train
# Original ADC Shape (50, 128, 128)
# Original Z_ADC Shape (50, 128, 128)
# Original Label Shape (50, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_358-VISIT_01 in Train
# Original ADC Shape (17, 160, 160)
# Original Z_ADC Shape (17, 160, 160)
# Original Label Shape (17, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_454-VISIT_01 in Train
# Original ADC Shape (60, 128, 128)
# Original Z_ADC Shape (60, 128, 128)
# Original Label Shape (60, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_299-VISIT_01 in Train
# Original ADC Shape (50, 128, 128)
# Original Z_ADC Shape (50, 128, 128)
# Original Label Shape (50, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_355-VISIT_01 in Train
# Original ADC Shape (50, 128, 128)
# Original Z_ADC Shape (50, 128, 128)
# Original Label Shape (50, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_312-VISIT_01 in Train
# Original ADC Shape (45, 256, 256)
# Original Z_ADC Shape (45, 256, 256)
# Original Label Shape (45, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_072-VISIT_01 in Train
# Original ADC Shape (19, 256, 256)
# Original Z_ADC Shape (19, 256, 256)
# Original Label Shape (19, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_062-VISIT_01 in Train
# Original ADC Shape (22, 160, 160)
# Original Z_ADC Shape (22, 160, 160)
# Original Label Shape (22, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_455-VISIT_01 in Train
# Original ADC Shape (48, 256, 256)
# Original Z_ADC Shape (48, 256, 256)
# Original Label Shape (48, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_070-VISIT_01 in Train
# Original ADC Shape (52, 128, 128)
# Original Z_ADC Shape (52, 128, 128)
# Original Label Shape (52, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_264-VISIT_01 in Train
# Original ADC Shape (34, 128, 128)
# Original Z_ADC Shape (34, 128, 128)
# Original Label Shape (34, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_350-VISIT_01 in Train
# Original ADC Shape (53, 128, 128)
# Original Z_ADC Shape (53, 128, 128)
# Original Label Shape (53, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_370-VISIT_01 in Train
# Original ADC Shape (40, 256, 256)
# Original Z_ADC Shape (40, 256, 256)
# Original Label Shape (40, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_077-VISIT_01 in Train
# Original ADC Shape (50, 128, 128)
# Original Z_ADC Shape (50, 128, 128)
# Original Label Shape (50, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_329-VISIT_01 in Train
# Original ADC Shape (46, 256, 256)
# Original Z_ADC Shape (46, 256, 256)
# Original Label Shape (46, 256, 256)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_125-VISIT_01 in Train
# Original ADC Shape (17, 160, 160)
# Original Z_ADC Shape (17, 160, 160)
# Original Label Shape (17, 160, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_456-VISIT_01 in Train
# Original ADC Shape (50, 128, 128)
# Original Z_ADC Shape (50, 128, 128)
# Original Label Shape (50, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_336-VISIT_01 in Train
# Common files for Val: 4
# Original ADC Shape (16, 128, 128)
# Original Z_ADC Shape (16, 128, 128)
# Original Label Shape (16, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_001-VISIT_01 in Val
# Original ADC Shape (21, 128, 128)
# Original Z_ADC Shape (21, 128, 128)
# Original Label Shape (21, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_002-VISIT_01 in Val
# Original ADC Shape (20, 144, 160)
# Original Z_ADC Shape (20, 144, 160)
# Original Label Shape (20, 144, 160)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_436-VISIT_01 in Val
# Original ADC Shape (51, 128, 128)
# Original Z_ADC Shape (51, 128, 128)
# Original Label Shape (51, 128, 128)
# Concatenated Map Shape (2, 32, 192, 192)
# Resampled Label Shape (32, 192, 192)
# Processed and saved for MGHNICU_302-VISIT_01 in Val
